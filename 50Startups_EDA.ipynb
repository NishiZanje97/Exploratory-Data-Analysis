# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv('/content/50_Startups.csv')
data.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
data.isnull().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
data.describe()
# Out:
#                  RND          ADMIN            MKT         PROFIT
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,linewidth=2)

# %%
dummy=pd.get_dummies(data.STATE)
dummy
# Out:
#     California  Florida  New York
# 0            0        0         1
# 1            1        0         0
# 2            0        1         0
# 3            0        0         1
# 4            0        1         0
# 5            0        0         1
# 6            1        0         0
# 7            0        1         0
# 8            0        0         1
# 9            1        0         0
# 10           0        1         0
# 11           1        0         0
# 12           0        1         0
# 13           1        0         0
# 14           0        1         0
# 15           0        0         1
# 16           1        0         0
# 17           0        0         1
# 18           0        1         0
# 19           0        0         1
# 20           1        0         0
# 21           0        0         1
# 22           0        1         0
# 23           0        1         0
# 24           0        0         1
# 25           1        0         0
# ...

# %%
df=pd.concat([dummy,data],axis=1)
df
# Out:
#     California  Florida  New York  ...        MKT       STATE     PROFIT
# 0            0        0         1  ...  471784.10    New York  192261.83
# 1            1        0         0  ...  443898.53  California  191792.06
# 2            0        1         0  ...  407934.54     Florida  191050.39
# 3            0        0         1  ...  383199.62    New York  182901.99
# 4            0        1         0  ...  366168.42     Florida  166187.94
# 5            0        0         1  ...  362861.36    New York  156991.12
# 6            1        0         0  ...  127716.82  California  156122.51
# 7            0        1         0  ...  323876.68     Florida  155752.60
# 8            0        0         1  ...  311613.29    New York  152211.77
# 9            1        0         0  ...  304981.62  California  149759.96
# 10           0        1         0  ...  229160.95     Florida  146121.95
# 11           1        0         0  ...  249744.55  California  144259.40
# ...

# %%
df1=df.drop(['ADMIN','STATE'],axis=1)
df1
# Out:
#     California  Florida  New York        RND        MKT     PROFIT
# 0            0        0         1  165349.20  471784.10  192261.83
# 1            1        0         0  162597.70  443898.53  191792.06
# 2            0        1         0  153441.51  407934.54  191050.39
# 3            0        0         1  144372.41  383199.62  182901.99
# 4            0        1         0  142107.34  366168.42  166187.94
# 5            0        0         1  131876.90  362861.36  156991.12
# 6            1        0         0  134615.46  127716.82  156122.51
# 7            0        1         0  130298.13  323876.68  155752.60
# 8            0        0         1  120542.52  311613.29  152211.77
# 9            1        0         0  123334.88  304981.62  149759.96
# 10           0        1         0  101913.08  229160.95  146121.95
# 11           1        0         0  100671.96  249744.55  144259.40
# 12           0        1         0   93863.75  249839.44  141585.52
# ...

# %%
sns.pairplot(df1)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df1.corr(),annot=True,linewidth=2)

# %%
x=df1.iloc[:,0:5].values
y=df1.iloc[:,5].values
x
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         4.4389853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         3.8319962e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         3.6616842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.2771682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.3029813e+05,
#         3.2387668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         3.1161329e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.2333488e+05,
#         3.0498162e+05],
# ...

# %%
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
reg=model.fit(X_train,Y_train)

# %%
y_predict=reg.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_predict)
# Out:
# 0.9225099972637228

# %%
df1
# Out:
#     California  Florida  New York        RND        MKT     PROFIT
# 0            0        0         1  165349.20  471784.10  192261.83
# 1            1        0         0  162597.70  443898.53  191792.06
# 2            0        1         0  153441.51  407934.54  191050.39
# 3            0        0         1  144372.41  383199.62  182901.99
# 4            0        1         0  142107.34  366168.42  166187.94
# 5            0        0         1  131876.90  362861.36  156991.12
# 6            1        0         0  134615.46  127716.82  156122.51
# 7            0        1         0  130298.13  323876.68  155752.60
# 8            0        0         1  120542.52  311613.29  152211.77
# 9            1        0         0  123334.88  304981.62  149759.96
# 10           0        1         0  101913.08  229160.95  146121.95
# 11           1        0         0  100671.96  249744.55  144259.40
# 12           0        1         0   93863.75  249839.44  141585.52
# ...

# %%
x1=df1.iloc[:,3].values
y1=df1.iloc[:,5].values

# %%
from sklearn.model_selection import train_test_split
X_train1,X_test1,Y_train1,Y_test1=train_test_split(x1,y1,test_size=0.2,random_state=42)
from sklearn import linear_model
model1=linear_model.LinearRegression()

# %%
reg=model1.fit((X_train1).reshape(-1,1),Y_train1)

# %%
y_predict1=reg.predict((X_test1).reshape(-1,1))
y_predict1
# Out:
# array([127862.20996405,  82250.56334619, 102255.72078164,  50190.4734756 ,
#        130136.88190548,  49799.36685472, 113638.0775288 , 104535.0534288 ,
#        103463.04843113, 123105.31102669])

# %%
from sklearn.metrics import r2_score
r2_score(Y_test1, y_predict1)
# Out:
# 0.9265108109341951

# %%
X_train1.shape
# Out:
# (40,)

# %%
sns.regplot(X_train1,Y_train1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
